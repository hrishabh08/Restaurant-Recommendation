# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ProcessedData.csv")
df.head()
# Out:
#           Name                                           Cuisines  \
# 0  Jyoti Vihar                                       south indian
# 1    WOW! Momo                          momos, fast food, tibetan
# 2      Zam Zam                                     biryani, rolls
# 3   Daily Bhoj                                            bengali
# 4       Behnam  biryani, north indian, mughlai, rolls, kebab, ...
#
#                 Area                                       Full_Address  \
# 0  Camac Street Area  3A/1, Ho Chi Minh Sarani, Camac Street Area, K...
# 1   Park Street Area  57, Park Street, Beside Vodafone Store, Park S...
# 2   Park Circus Area  28/A, Syed Amir Ali Avenue, Park Circus Area, ...
# 3             Topsia               139/1G, Tljala Road, Topsia, Kolkata
# 4             Topsia  139/1G, Tiljala Road, Near OYO Townhouse 229, ...
#
#    AverageCost  Total Reviews  Total Ratings Cost Category  \
# 0          300           6428            4.1      midrange
# 1          350          11569            4.1      midrange
# 2          500          85001            4.3     expensive
# 3          150           2260            3.9     cheapeats
# 4          200            151            2.9      midrange
#
#                                       Features  \
# 0  homedelivery takeaway vegonly indoorseating
# 1         homedelivery takeaway  indoorseating
# 2         homedelivery takeaway  indoorseating
# 3                              homedelivery
# 4                      homedelivery takeaway
#
#                                     Testing Features  \
# 0  homedelivery takeaway vegonly indoorseating mi...
# 1       homedelivery takeaway indoorseating midrange
# 2      homedelivery takeaway indoorseating expensive
# 3                             homedelivery cheapeats
# 4                     homedelivery takeaway midrange
#
#                                         bag_of_words
# 0  south indian homedelivery takeaway vegonly ind...
# 1  momos fast food tibetan homedelivery takeaway ...
# 2  biryani rolls homedelivery takeaway indoorseat...
# 3                     bengali homedelivery cheapeats
# 4  biryani north indian mughlai rolls kebab awadh...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
def process_sentences(text):
    temp_sent =[]

    # Tokenize words
    words = word_tokenize(text)
    
    for word in words: 
        # Remove stop words and non alphabet tokens
        if word not in stop_words and word.isalpha(): 
            temp_sent.append(word)

    # Some other clean-up
    full_sentence = ' '.join(temp_sent)
    
    return full_sentence

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import manhattan_distances

# %%
def Evaluate_Model_Euclidean(description,Area):
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy() 
    data = data[data['Area'] == Area]
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    # Init a TF-IDF vectorizer
    tfidfvec = TfidfVectorizer()
    # Fit data on processed reviews
    vec = tfidfvec.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])
    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])
    # Calculate the similarity for the differnt models
    distance = euclidean_distances(description_vector, features)
    similarity = 1/(1+distance)
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %%
def Evaluate_Model_Manhattan(description,Area):
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy() 
    data = data[data['Area'] == Area]
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    # Init a TF-IDF vectorizer
    tfidfvec = TfidfVectorizer()
    # Fit data on processed reviews
    vec = tfidfvec.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])
    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])
    # Calculate the similarity for the differnt models
    distance = manhattan_distances(description_vector, features)
    similarity = 1/(1+distance)
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %%
def Evaluate_Model_LinearKernel(description,Area):
    
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy()
    data = data[data['Area'] == Area]  
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    
    # Init a TF-IDF vectorizer
    tfidfvec = TfidfVectorizer()

    # Fit data on processed reviews
    vec = tfidfvec.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])

    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])

    # Calculate the similarity for the differnt models
    similarity = linear_kernel(description_vector, features)
    # Add similarities to data frame
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %%
def Evaluate_Model_CosineSimilarity(description,Area):
    
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy()
    data = data[data['Area'] == Area]  
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    
    # Init a TF-IDF vectorizer
    tfidfvec = TfidfVectorizer()

    # Fit data on processed reviews
    vec = tfidfvec.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])

    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])

    # Calculate the similarity for the differnt models
    similarity = cosine_similarity(description_vector, features)
    # Add similarities to data frame
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %%
def Evaluate_Model_TFIDF_MaxFeatures(description,Area):
    
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy()
    data = data[data['Area'] == Area]  
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    
    # Init a TF-IDF vectorizer
    tfidfvec = TfidfVectorizer(max_features=2)

    # Fit data on processed reviews
    vec = tfidfvec.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])

    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])

    # Calculate the similarity for the differnt models
    similarity = cosine_similarity(description_vector, features)
    # Add similarities to data frame
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %%
def Evaluate_Model_CountVec(description,Area):
    
    # Convert user input to lowercase
    description = description.lower()
    data = df.copy()
    data = data[data['Area'] == Area]  
    # Process user description text input 
    description = process_sentences(description)
    description = description.strip()
    
    # Init a TF-IDF vectorizer
    contVect = CountVectorizer()

    # Fit data on processed reviews
    vec = contVect.fit(data["bag_of_words"])
    features = vec.transform(data["bag_of_words"])

    # Transform user input data based on fitted model
    description_vector =  vec.transform([description])

    # Calculate the similarity for the differnt models
    similarity = cosine_similarity(description_vector, features)
    # Add similarities to data frame
    data['similarity'] = similarity[0]
    # Sort data frame by similarities
    data.sort_values(by='similarity', ascending=False, inplace=True)
    return data[['Name', 'Area', 'AverageCost', 'Cuisines','Testing Features', 'Total Ratings', 'similarity']].head(5)

# %% [markdown]
# ### Testing for model

# %% [markdown]
# ### Test Case 1

# %%
user_choice_cuisine ='momos biryani'
user_choice_Features = 'indoorseating'
user_choice_CostCategory ='midrange'
user_choice_Area='Park Street Area'

description = user_choice_cuisine + ' ' + user_choice_Features+' '+user_choice_CostCategory

# %%
Evaluate_Model_Euclidean(description=description,Area=user_choice_Area)
# Out:
#                   Name              Area  AverageCost  \
# 150    New Noodle King  Park Street Area          400
# 631        Noodle Time  Park Street Area          400
# 1            WOW! Momo  Park Street Area          350
# 261  The Biryani Mahal  Park Street Area          400
# 10                 KFC  Park Street Area          400
#
#                                             Cuisines  \
# 150                          chinese, seafood, momos
# 631                          chinese, momos, seafood
# 1                          momos, fast food, tibetan
# 261                            biryani, north indian
# 10   burger, fast food, biryani, desserts, beverages
#
#                                  Testing Features  Total Ratings  similarity
# 150  homedelivery takeaway indoorseating midrange            3.9    0.535730
# 631  homedelivery takeaway indoorseating midrange            4.0    0.535730
# 1    homedelivery takeaway indoorseating midrange            4.1    0.509509
# 261  homedelivery takeaway indoorseating midrange            3.5    0.507606
# 10   homedelivery takeaway indoorseating midrange            4.2    0.473708

# %%
Evaluate_Model_Manhattan(description=description,Area=user_choice_Area)
# Out:
#                           Name              Area  AverageCost  \
# 631                Noodle Time  Park Street Area          400
# 150            New Noodle King  Park Street Area          400
# 261          The Biryani Mahal  Park Street Area          400
# 1                    WOW! Momo  Park Street Area          350
# 229  Kaaram-The Andhra Kitchen  Park Street Area          500
#
#                       Cuisines                               Testing Features  \
# 631    chinese, momos, seafood   homedelivery takeaway indoorseating midrange
# 150    chinese, seafood, momos   homedelivery takeaway indoorseating midrange
# 261      biryani, north indian   homedelivery takeaway indoorseating midrange
# 1    momos, fast food, tibetan   homedelivery takeaway indoorseating midrange
# 229            biryani, andhra  homedelivery takeaway indoorseating expensive
#
#      Total Ratings  similarity
# 631            4.0    0.344728
# 150            3.9    0.344728
# 261            3.5    0.323873
# 1              4.1    0.301257
# 229            4.3    0.278262

# %%
Evaluate_Model_CosineSimilarity(description=description,Area=user_choice_Area)
# Out:
#                   Name              Area  AverageCost  \
# 150    New Noodle King  Park Street Area          400
# 631        Noodle Time  Park Street Area          400
# 1            WOW! Momo  Park Street Area          350
# 261  The Biryani Mahal  Park Street Area          400
# 10                 KFC  Park Street Area          400
#
#                                             Cuisines  \
# 150                          chinese, seafood, momos
# 631                          chinese, momos, seafood
# 1                          momos, fast food, tibetan
# 261                            biryani, north indian
# 10   burger, fast food, biryani, desserts, beverages
#
#                                  Testing Features  Total Ratings  similarity
# 150  homedelivery takeaway indoorseating midrange            3.9    0.624491
# 631  homedelivery takeaway indoorseating midrange            4.0    0.624491
# 1    homedelivery takeaway indoorseating midrange            4.1    0.536630
# 261  homedelivery takeaway indoorseating midrange            3.5    0.529519
# 10   homedelivery takeaway indoorseating midrange            4.2    0.382833

# %%
Evaluate_Model_LinearKernel(description=description,Area=user_choice_Area)
# Out:
#                   Name              Area  AverageCost  \
# 150    New Noodle King  Park Street Area          400
# 631        Noodle Time  Park Street Area          400
# 1            WOW! Momo  Park Street Area          350
# 261  The Biryani Mahal  Park Street Area          400
# 10                 KFC  Park Street Area          400
#
#                                             Cuisines  \
# 150                          chinese, seafood, momos
# 631                          chinese, momos, seafood
# 1                          momos, fast food, tibetan
# 261                            biryani, north indian
# 10   burger, fast food, biryani, desserts, beverages
#
#                                  Testing Features  Total Ratings  similarity
# 150  homedelivery takeaway indoorseating midrange            3.9    0.624491
# 631  homedelivery takeaway indoorseating midrange            4.0    0.624491
# 1    homedelivery takeaway indoorseating midrange            4.1    0.536630
# 261  homedelivery takeaway indoorseating midrange            3.5    0.529519
# 10   homedelivery takeaway indoorseating midrange            4.2    0.382833

# %%
Evaluate_Model_TFIDF_MaxFeatures(description=description,Area=user_choice_Area)
# Out:
#                        Name              Area  AverageCost  \
# 1                 WOW! Momo  Park Street Area          350
# 969             Wow Chicken  Park Street Area          150
# 963        Schezwan Kitchen  Park Street Area          100
# 955                 Waldorf  Park Street Area         1000
# 954  Gabbar's Bar & Kitchen  Park Street Area         1500
#
#                                       Cuisines  \
# 1                    momos, fast food, tibetan
# 969     burger, fast food, american, beverages
# 963    north indian, chinese, burger, sandwich
# 955                             chinese, asian
# 954  north indian, chinese, italian, beverages
#
#                                   Testing Features  Total Ratings  similarity
# 1     homedelivery takeaway indoorseating midrange            4.1         0.0
# 969                homedelivery takeaway cheapeats            4.0         0.0
# 963                homedelivery takeaway cheapeats            3.9         0.0
# 955  homedelivery takeaway indoorseating expensive            3.9         0.0
# 954  homedelivery takeaway indoorseating expensive            4.0         0.0

# %%
Evaluate_Model_CountVec(description=description,Area=user_choice_Area)
# Out:
#                   Name              Area  AverageCost  \
# 631        Noodle Time  Park Street Area          400
# 261  The Biryani Mahal  Park Street Area          400
# 150    New Noodle King  Park Street Area          400
# 1            WOW! Momo  Park Street Area          350
# 10                 KFC  Park Street Area          400
#
#                                             Cuisines  \
# 631                          chinese, momos, seafood
# 261                            biryani, north indian
# 150                          chinese, seafood, momos
# 1                          momos, fast food, tibetan
# 10   burger, fast food, biryani, desserts, beverages
#
#                                  Testing Features  Total Ratings  similarity
# 631  homedelivery takeaway indoorseating midrange            4.0    0.566947
# 261  homedelivery takeaway indoorseating midrange            3.5    0.566947
# 150  homedelivery takeaway indoorseating midrange            3.9    0.566947
# 1    homedelivery takeaway indoorseating midrange            4.1    0.530330
# 10   homedelivery takeaway indoorseating midrange            4.2    0.474342

# %% [markdown]
# ### Test Case 8

# %%
# User input
user_choice_cuisine ='chinese'
user_choice_Features = 'homedelivery'
user_choice_CostCategory ='expensive'
user_choice_Area='Sealdah Area'

description = user_choice_cuisine + ' ' + user_choice_Features+' '+user_choice_CostCategory

# %%
Evaluate_Model_CosineSimilarity(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.786977
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.651254
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.651254
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.605871
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.562909

# %%
Evaluate_Model_LinearKernel(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.786977
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.651254
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.651254
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.605871
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.562909

# %%
Evaluate_Model_LinearKernel(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.786977
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.651254
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.651254
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.605871
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.562909

# %%
Evaluate_Model_Euclidean(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.605062
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.544912
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.544912
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.529706
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.516802

# %%
Evaluate_Model_Manhattan(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 3118                         biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.369002
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.352240
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.320212
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.320212
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.306408

# %% [markdown]
# ### Test Case 9

# %%
# User input
user_choice_cuisine ='biryani'
user_choice_Features = 'Indoorseating'
user_choice_CostCategory ='expensive'
user_choice_Area='Baguihati'

description = user_choice_cuisine + ' ' + user_choice_Features+' '+user_choice_CostCategory

# %%
Evaluate_Model_CosineSimilarity(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.786977
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.651254
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.651254
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.605871
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.562909

# %%
Evaluate_Model_LinearKernel(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.786977
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.651254
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.651254
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.605871
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.562909

# %%
Evaluate_Model_Euclidean(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
# 3118                         biryani
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.605062
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.544912
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.544912
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.529706
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.516802

# %%
Evaluate_Model_Manhattan(description=description,Area=user_choice_Area)
# Out:
#                            Name       Area  AverageCost  \
# 2966              Food Junction  Baguihati          500
# 3118  New Arsalan Biryani House  Baguihati          200
# 1642    The Floresta Restaurant  Baguihati          700
# 1606                 Paramparaa  Baguihati          450
# 3185          Master Chef Pizza  Baguihati          500
#
#                             Cuisines  \
# 2966  chinese, north indian, biryani
# 3118                         biryani
# 1642           chinese, north indian
# 1606           north indian, chinese
# 3185                fast food, pizza
#
#                                    Testing Features  Total Ratings  similarity
# 2966  homedelivery takeaway indoorseating expensive            3.7    0.369002
# 3118   homedelivery takeaway indoorseating midrange            0.0    0.352240
# 1642  homedelivery takeaway indoorseating expensive            3.7    0.320212
# 1606  homedelivery takeaway indoorseating expensive            4.0    0.320212
# 3185  homedelivery takeaway indoorseating expensive            3.6    0.306408
